# %%
# !python ./test_interfaces.py
# Out:
# Testing Problem 1 Interface Compliance
# ...
#
# TestEnvironmentInterface:
#   ✓ test_environment_initialization
#   ✓ test_position_conversion_interfaces
#   ✓ test_reset_interface
#   ✓ test_reward_function_interface
#   ✓ test_step_interface
#   ✓ test_terminal_check_interface
#   ✓ test_transition_probability_interface
#
# TestValueIterationInterface:
#   ✓ test_bellman_backup_interface
#   ✓ test_bellman_error_interface
#   ✓ test_compute_q_values_interface
#   ✓ test_extract_policy_interface
#   ✓ test_solve_interface
#   ✓ test_value_iteration_initialization
#
# TestQIterationInterface:
#   ✓ test_bellman_error_interface
#   ✓ test_bellman_update_interface
#   ✓ test_extract_policy_interface
#   ✓ test_extract_values_interface
#   ✓ test_q_iteration_initialization
#   ✓ test_solve_interface
#
# ...
# Results: 19/19 tests passed
# All interface tests passed!

# %%
# !python ./train.py
# Out:
# Running Value Iteration...
# Value Iteration converged in 136 iterations.
#
# Running Q-Iteration...
# Q-Iteration converged in 136 iterations.
#
# Comparing algorithms...
# Policies match? False
# Values similar? False
#
# Results saved to 'results/' directory.

# %%
# !python ./visualize.py
# Out:
# All visualization images saved to results/visualizations/
